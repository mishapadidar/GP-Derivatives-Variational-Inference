# %% [markdown]
# # Mount St. Helens Countour Dataset

# %%
import math
import numpy as np
import torch
import gpytorch
import tqdm
import random
from matplotlib import pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
import sys
import sys
import scipy.io
import torch
import numpy as np 
sys.path.append("../directionalvi")
#sys.path.append("../../data")
sys.path.append("../directionalvi/utils")
from directional_vi import train_gp
from metrics import MSE
from metrics import MAE
# Out:
# in Directional Grad Variational Strategy.py

# %%
#load data
mat = scipy.io.loadmat('MtSH.mat')
x = torch.tensor(np.float64(mat['mth_points'])).float()
y = torch.tensor(np.float64(mat['mth_verts'])).float()
y = y - torch.mean(y)
dy = torch.tensor(np.float64(mat['mth_grads'])).float()
data = torch.cat((y, dy), dim = 1).float()
full_data = torch.cat((x, data), dim=1).float() #location concatenated with y and dy values

# %% [markdown]
# # Filter and Round Dataset (If Applicable)

# %%
temp_full_data = np.array(full_data)
def fun(x, val = 250):
    if x[0]>250 or x[1]>250:       
        return False 
    else:
        return True
filtered = filter(fun, temp_full_data)
#for item in filtered:
#    print(item)
arr = [item for item in filtered]
len_arr = len(arr)
len_arr = len_arr - len_arr%100
arr = arr[:len_arr]
#full_data_truncated = torch.tensor(arr)
print(len(arr))
# Out:
# 900

# %%
xs1 = [item[0] for item in arr]
xs2 = [item[1] for item in arr]
plt.scatter(xs1, xs2)

# %%
#recover x and data from filtered concatenated values
x = torch.tensor([item[0:2] for item in arr])
data = torch.tensor([item[2:] for item in arr])
data[:, 0] = data[:, 0] - torch.mean(data[:, 0]) #normalize
print(max(data[:, 0]))
print(min(data[:, 0]))
# Out:
# tensor(351.0277)
# tensor(-170.4590)

# %%
# data parameters
n  = data.shape[0] 
dim = 2
n_test = n//10

# training params
num_inducing = 400
num_directions = 1
minibatch_size = n_test #how does minibatch size impact convergence rate
num_epochs = 1500

#print
print("n is: ", n)
print("n_test is: ", n_test)
print("num_inducing is:", num_inducing)
print("num_directions is: ", num_directions)

# generate training data
dataset = TensorDataset(x, data)
# Out:
# n is:  900
# n_test is:  90
# num_inducing is: 400
# num_directions is:  1

# %% [markdown]
# # Plotting

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [n_test, n-n_test], generator=torch.Generator().manual_seed(42))

# %%
train_dataset
train_loader  = DataLoader(train_dataset, batch_size=minibatch_size, shuffle=True)
dim = len(train_dataset[0][0])
n_samples = len(train_dataset)

# %%
n_samples
# Out:
# 90

# %%
model,likelihood = train_gp(train_dataset,
                      num_inducing=num_inducing,
                      num_directions=num_directions,
                      minibatch_size = minibatch_size,
                      minibatch_dim = num_directions,
                      num_epochs =num_epochs
                      )
# Out:
# Epoch:   0%|                                                                                  | 0/1500 [00:00<?, ?it/s]
# Epoch:   0%|                                                                    | 0/1500 [00:00<?, ?it/s, loss=4.68e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.61it/s]
# Epoch:   0%|                                                            | 1/1500 [00:00<07:08,  3.50it/s, loss=4.68e+3]
# Epoch:   0%|                                                            | 1/1500 [00:00<07:08,  3.50it/s, loss=4.64e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.94it/s]
# Epoch:   0%|                                                            | 2/1500 [00:00<06:58,  3.58it/s, loss=4.64e+3]
# Epoch:   0%|                                                            | 2/1500 [00:00<06:58,  3.58it/s, loss=4.61e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.30it/s]
# Epoch:   0%|                                                            | 3/1500 [00:00<07:12,  3.46it/s, loss=4.61e+3]
# Epoch:   0%|                                                            | 3/1500 [00:00<07:12,  3.46it/s, loss=4.58e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.36it/s]
# Epoch:   0%|▏                                                           | 4/1500 [00:01<07:20,  3.40it/s, loss=4.58e+3]
# Epoch:   0%|▏                                                           | 4/1500 [00:01<07:20,  3.40it/s, loss=4.54e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.22it/s]
# Epoch:   0%|▏                                                           | 5/1500 [00:01<07:32,  3.31it/s, loss=4.54e+3]
# Epoch:   0%|▏                                                           | 5/1500 [00:01<07:32,  3.31it/s, loss=4.51e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.41it/s]
# Epoch:   0%|▏                                                           | 6/1500 [00:01<07:31,  3.31it/s, loss=4.51e+3]
# Epoch:   0%|▏                                                           | 6/1500 [00:01<07:31,  3.31it/s, loss=4.48e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.17it/s]
# Epoch:   0%|▎                                                           | 7/1500 [00:02<07:40,  3.24it/s, loss=4.48e+3]
# Epoch:   0%|▎                                                           | 7/1500 [00:02<07:40,  3.24it/s, loss=4.45e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.10it/s]
# Epoch:   1%|▎                                                           | 8/1500 [00:02<07:49,  3.18it/s, loss=4.45e+3]
# Epoch:   1%|▎                                                           | 8/1500 [00:02<07:49,  3.18it/s, loss=4.42e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.98it/s]
# Epoch:   1%|▎                                                           | 9/1500 [00:02<08:02,  3.09it/s, loss=4.42e+3]
# Epoch:   1%|▎                                                           | 9/1500 [00:02<08:02,  3.09it/s, loss=4.39e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.27it/s]
# Epoch:   1%|▍                                                          | 10/1500 [00:03<07:58,  3.11it/s, loss=4.39e+3]
# Epoch:   1%|▍                                                          | 10/1500 [00:03<07:58,  3.11it/s, loss=4.36e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.27it/s]
# Epoch:   1%|▍                                                          | 11/1500 [00:03<07:55,  3.13it/s, loss=4.36e+3]
# Epoch:   1%|▍                                                          | 11/1500 [00:03<07:55,  3.13it/s, loss=4.32e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.75it/s]
# Epoch:   1%|▍                                                          | 12/1500 [00:03<08:19,  2.98it/s, loss=4.32e+3]
# Epoch:   1%|▍                                                          | 12/1500 [00:03<08:19,  2.98it/s, loss=4.29e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.90it/s]
# Epoch:   1%|▌                                                          | 13/1500 [00:04<08:27,  2.93it/s, loss=4.29e+3]
# Epoch:   1%|▌                                                          | 13/1500 [00:04<08:27,  2.93it/s, loss=4.27e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.19it/s]
# Epoch:   1%|▌                                                          | 14/1500 [00:04<08:18,  2.98it/s, loss=4.27e+3]
# Epoch:   1%|▌                                                          | 14/1500 [00:04<08:18,  2.98it/s, loss=4.24e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.00it/s]
# Epoch:   1%|▌                                                          | 15/1500 [00:04<08:19,  2.97it/s, loss=4.24e+3]
# Epoch:   1%|▌                                                          | 15/1500 [00:04<08:19,  2.97it/s, loss=4.21e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.18it/s]
# Epoch:   1%|▋                                                          | 16/1500 [00:05<08:12,  3.01it/s, loss=4.21e+3]
# Epoch:   1%|▋                                                          | 16/1500 [00:05<08:12,  3.01it/s, loss=4.18e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.36it/s]
# Epoch:   1%|▋                                                          | 17/1500 [00:05<08:00,  3.09it/s, loss=4.18e+3]
# Epoch:   1%|▋                                                          | 17/1500 [00:05<08:00,  3.09it/s, loss=4.15e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.73it/s]
# Epoch:   1%|▋                                                          | 18/1500 [00:05<07:38,  3.23it/s, loss=4.15e+3]
# Epoch:   1%|▋                                                          | 18/1500 [00:05<07:38,  3.23it/s, loss=4.12e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.26it/s]
# Epoch:   1%|▋                                                          | 19/1500 [00:06<07:40,  3.22it/s, loss=4.12e+3]
# Epoch:   1%|▋                                                          | 19/1500 [00:06<07:40,  3.22it/s, loss=4.09e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.28it/s]
# Epoch:   1%|▊                                                          | 20/1500 [00:06<07:41,  3.21it/s, loss=4.09e+3]
# Epoch:   1%|▊                                                          | 20/1500 [00:06<07:41,  3.21it/s, loss=4.07e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.12it/s]
# Epoch:   1%|▊                                                          | 21/1500 [00:06<07:48,  3.16it/s, loss=4.07e+3]
# Epoch:   1%|▊                                                          | 21/1500 [00:06<07:48,  3.16it/s, loss=4.04e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.26it/s]
# Epoch:   1%|▊                                                          | 22/1500 [00:06<07:14,  3.40it/s, loss=4.04e+3]
# Epoch:   1%|▊                                                          | 22/1500 [00:06<07:14,  3.40it/s, loss=4.01e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.07it/s]
# Epoch:   2%|▉                                                          | 23/1500 [00:07<06:56,  3.55it/s, loss=4.01e+3]
# Epoch:   2%|▉                                                          | 23/1500 [00:07<06:56,  3.55it/s, loss=3.99e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
# Epoch:   2%|▉                                                          | 24/1500 [00:07<07:09,  3.44it/s, loss=3.99e+3]
# Epoch:   2%|▉                                                          | 24/1500 [00:07<07:09,  3.44it/s, loss=3.96e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.75it/s]
# Epoch:   2%|▉                                                          | 25/1500 [00:07<07:00,  3.50it/s, loss=3.96e+3]
# Epoch:   2%|▉                                                          | 25/1500 [00:07<07:00,  3.50it/s, loss=3.94e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.98it/s]
# Epoch:   2%|█                                                          | 26/1500 [00:08<06:48,  3.61it/s, loss=3.94e+3]
# Epoch:   2%|█                                                          | 26/1500 [00:08<06:48,  3.61it/s, loss=3.91e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.32it/s]
# Epoch:   2%|█                                                          | 27/1500 [00:08<07:02,  3.49it/s, loss=3.91e+3]
# Epoch:   2%|█                                                          | 27/1500 [00:08<07:02,  3.49it/s, loss=3.89e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.25it/s]
# Epoch:   2%|█                                                          | 28/1500 [00:08<07:15,  3.38it/s, loss=3.89e+3]
# Epoch:   2%|█                                                          | 28/1500 [00:08<07:15,  3.38it/s, loss=3.86e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.30it/s]
# Epoch:   2%|█▏                                                         | 29/1500 [00:08<07:22,  3.33it/s, loss=3.86e+3]
# Epoch:   2%|█▏                                                         | 29/1500 [00:09<07:22,  3.33it/s, loss=3.84e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.47it/s]
# Epoch:   2%|█▏                                                         | 30/1500 [00:09<07:21,  3.33it/s, loss=3.84e+3]
# Epoch:   2%|█▏                                                         | 30/1500 [00:09<07:21,  3.33it/s, loss=3.81e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.02it/s]
# Epoch:   2%|█▏                                                         | 31/1500 [00:09<07:39,  3.20it/s, loss=3.81e+3]
# Epoch:   2%|█▏                                                         | 31/1500 [00:09<07:39,  3.20it/s, loss=3.79e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.62it/s]
# Epoch:   2%|█▎                                                         | 32/1500 [00:09<08:12,  2.98it/s, loss=3.79e+3]
# Epoch:   2%|█▎                                                         | 32/1500 [00:10<08:12,  2.98it/s, loss=3.76e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.46it/s]
# Epoch:   2%|█▎                                                         | 33/1500 [00:10<07:55,  3.09it/s, loss=3.76e+3]
# Epoch:   2%|█▎                                                         | 33/1500 [00:10<07:55,  3.09it/s, loss=3.74e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.00it/s]
# Epoch:   2%|█▎                                                         | 34/1500 [00:10<08:02,  3.04it/s, loss=3.74e+3]
# Epoch:   2%|█▎                                                         | 34/1500 [00:10<08:02,  3.04it/s, loss=3.72e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.60it/s]
# Epoch:   2%|█▍                                                         | 35/1500 [00:11<08:33,  2.85it/s, loss=3.72e+3]
# Epoch:   2%|█▍                                                          | 35/1500 [00:11<08:33,  2.85it/s, loss=3.7e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.99it/s]
# Epoch:   2%|█▍                                                          | 36/1500 [00:11<08:29,  2.88it/s, loss=3.7e+3]
# Epoch:   2%|█▍                                                         | 36/1500 [00:11<08:29,  2.88it/s, loss=3.67e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.32it/s]
# Epoch:   2%|█▍                                                         | 37/1500 [00:11<08:12,  2.97it/s, loss=3.67e+3]
# Epoch:   2%|█▍                                                         | 37/1500 [00:11<08:12,  2.97it/s, loss=3.65e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.27it/s]
# Epoch:   3%|█▍                                                         | 38/1500 [00:11<08:03,  3.03it/s, loss=3.65e+3]
# Epoch:   3%|█▍                                                         | 38/1500 [00:12<08:03,  3.03it/s, loss=3.63e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.14it/s]
# Epoch:   3%|█▌                                                         | 39/1500 [00:12<08:00,  3.04it/s, loss=3.63e+3]
# Epoch:   3%|█▌                                                         | 39/1500 [00:12<08:00,  3.04it/s, loss=3.61e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.11it/s]
# Epoch:   3%|█▌                                                         | 40/1500 [00:12<08:01,  3.03it/s, loss=3.61e+3]
# Epoch:   3%|█▌                                                         | 40/1500 [00:12<08:01,  3.03it/s, loss=3.59e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.61it/s]
# Epoch:   3%|█▌                                                         | 41/1500 [00:12<07:42,  3.16it/s, loss=3.59e+3]
# Epoch:   3%|█▌                                                         | 41/1500 [00:13<07:42,  3.16it/s, loss=3.57e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.77it/s]
# Epoch:   3%|█▋                                                         | 42/1500 [00:13<07:22,  3.30it/s, loss=3.57e+3]
# Epoch:   3%|█▋                                                         | 42/1500 [00:13<07:22,  3.30it/s, loss=3.54e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.46it/s]
# Epoch:   3%|█▋                                                         | 43/1500 [00:13<07:19,  3.31it/s, loss=3.54e+3]
# Epoch:   3%|█▋                                                         | 43/1500 [00:13<07:19,  3.31it/s, loss=3.52e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.57it/s]
# Epoch:   3%|█▋                                                         | 44/1500 [00:13<07:13,  3.36it/s, loss=3.52e+3]
# Epoch:   3%|█▊                                                          | 44/1500 [00:13<07:13,  3.36it/s, loss=3.5e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.26it/s]
# Epoch:   3%|█▊                                                          | 45/1500 [00:14<07:21,  3.30it/s, loss=3.5e+3]
# Epoch:   3%|█▊                                                         | 45/1500 [00:14<07:21,  3.30it/s, loss=3.48e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.39it/s]
#
+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.42it/s]
# Epoch:   4%|██▍                                                        | 61/1500 [00:19<07:13,  3.32it/s, loss=3.21e+3]
# Epoch:   4%|██▍                                                        | 61/1500 [00:19<07:13,  3.32it/s, loss=3.19e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.24it/s]
# Epoch:   4%|██▍                                                        | 62/1500 [00:19<07:20,  3.27it/s, loss=3.19e+3]
# Epoch:   4%|██▍                                                        | 62/1500 [00:19<07:20,  3.27it/s, loss=3.18e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.16it/s]
# Epoch:   4%|██▍                                                        | 63/1500 [00:19<07:26,  3.22it/s, loss=3.18e+3]
# Epoch:   4%|██▍                                                        | 63/1500 [00:19<07:26,  3.22it/s, loss=3.16e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.58it/s]
# Epoch:   4%|██▌                                                        | 64/1500 [00:19<07:16,  3.29it/s, loss=3.16e+3]
# Epoch:   4%|██▌                                                        | 64/1500 [00:20<07:16,  3.29it/s, loss=3.14e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.52it/s]
# Epoch:   4%|██▌                                                        | 65/1500 [00:20<07:11,  3.33it/s, loss=3.14e+3]
# Epoch:   4%|██▌                                                        | 65/1500 [00:20<07:11,  3.33it/s, loss=3.13e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.30it/s]
# Epoch:   4%|██▌                                                        | 66/1500 [00:20<07:15,  3.30it/s, loss=3.13e+3]
# Epoch:   4%|██▌                                                        | 66/1500 [00:20<07:15,  3.30it/s, loss=3.11e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.33it/s]
# Epoch:   4%|██▋                                                        | 67/1500 [00:20<07:16,  3.28it/s, loss=3.11e+3]
# Epoch:   4%|██▋                                                         | 67/1500 [00:20<07:16,  3.28it/s, loss=3.1e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.04it/s]
# Epoch:   5%|██▋                                                         | 68/1500 [00:21<07:30,  3.18it/s, loss=3.1e+3]
# Epoch:   5%|██▋                                                        | 68/1500 [00:21<07:30,  3.18it/s, loss=3.08e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.24it/s]
# Epoch:   5%|██▋                                                        | 69/1500 [00:21<07:31,  3.17it/s, loss=3.08e+3]
# Epoch:   5%|██▋                                                        | 69/1500 [00:21<07:31,  3.17it/s, loss=3.07e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.64it/s]
# Epoch:   5%|██▊                                                        | 70/1500 [00:21<07:16,  3.28it/s, loss=3.07e+3]
# Epoch:   5%|██▊                                                        | 70/1500 [00:21<07:16,  3.28it/s, loss=3.05e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.65it/s]
# Epoch:   5%|██▊                                                        | 71/1500 [00:22<07:05,  3.36it/s, loss=3.05e+3]
# Epoch:   5%|██▊                                                        | 71/1500 [00:22<07:05,  3.36it/s, loss=3.04e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.89it/s]
# Epoch:   5%|██▊                                                        | 72/1500 [00:22<06:50,  3.48it/s, loss=3.04e+3]
# Epoch:   5%|██▊                                                        | 72/1500 [00:22<06:50,  3.48it/s, loss=3.02e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.70it/s]
# Epoch:   5%|██▊                                                        | 73/1500 [00:22<06:46,  3.51it/s, loss=3.02e+3]
# Epoch:   5%|██▊                                                        | 73/1500 [00:22<06:46,  3.51it/s, loss=3.01e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.36it/s]
# Epoch:   5%|██▉                                                        | 74/1500 [00:22<06:54,  3.44it/s, loss=3.01e+3]
# Epoch:   5%|██▉                                                        | 74/1500 [00:23<06:54,  3.44it/s, loss=2.99e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.39it/s]
# Epoch:   5%|██▉                                                        | 75/1500 [00:23<06:59,  3.40it/s, loss=2.99e+3]
# Epoch:   5%|██▉                                                        | 75/1500 [00:23<06:59,  3.40it/s, loss=2.98e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.25it/s]
# Epoch:   5%|██▉                                                        | 76/1500 [00:23<07:09,  3.32it/s, loss=2.98e+3]
# Epoch:   5%|██▉                                                        | 76/1500 [00:23<07:09,  3.32it/s, loss=2.97e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.17it/s]
# Epoch:   5%|███                                                        | 77/1500 [00:23<07:19,  3.24it/s, loss=2.97e+3]
# Epoch:   5%|███                                                        | 77/1500 [00:23<07:19,  3.24it/s, loss=2.95e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.65it/s]
# Epoch:   5%|███                                                        | 78/1500 [00:24<07:08,  3.32it/s, loss=2.95e+3]
# Epoch:   5%|███                                                        | 78/1500 [00:24<07:08,  3.32it/s, loss=2.94e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.61it/s]
# Epoch:   5%|███                                                        | 79/1500 [00:24<07:01,  3.37it/s, loss=2.94e+3]
# Epoch:   5%|███                                                        | 79/1500 [00:24<07:01,  3.37it/s, loss=2.92e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.89it/s]
# Epoch:   5%|███▏                                                       | 80/1500 [00:24<06:47,  3.48it/s, loss=2.92e+3]
# Epoch:   5%|███▏                                                       | 80/1500 [00:24<06:47,  3.48it/s, loss=2.91e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.65it/s]
# Epoch:   5%|███▏                                                       | 81/1500 [00:24<06:45,  3.50it/s, loss=2.91e+3]
# Epoch:   5%|███▏                                                        | 81/1500 [00:25<06:45,  3.50it/s, loss=2.9e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.95it/s]
# Epoch:   5%|███▎                                                        | 82/1500 [00:25<06:34,  3.60it/s, loss=2.9e+3]
# Epoch:   5%|███▏                                                       | 82/1500 [00:25<06:34,  3.60it/s, loss=2.88e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.81it/s]
# Epoch:   6%|███▎                                                       | 83/1500 [00:25<07:09,  3.30it/s, loss=2.88e+3]
# Epoch:   6%|███▎                                                       | 83/1500 [00:25<07:09,  3.30it/s, loss=2.87e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.39it/s]
# Epoch:   6%|███▎                                                       | 84/1500 [00:25<07:09,  3.30it/s, loss=2.87e+3]
# Epoch:   6%|███▎                                                       | 84/1500 [00:25<07:09,  3.30it/s, loss=2.86e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.41it/s]
# Epoch:   6%|███▎                                                       | 85/1500 [00:26<07:08,  3.30it/s, loss=2.86e+3]
# Epoch:   6%|███▎                                                       | 85/1500 [00:26<07:08,  3.30it/s, loss=2.85e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
# Epoch:   6%|███▍                                                       | 86/1500 [00:26<07:11,  3.28it/s, loss=2.85e+3]
# Epoch:   6%|███▍                                                       | 86/1500 [00:26<07:11,  3.28it/s, loss=2.83e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.66it/s]
# Epoch:   6%|███▍                                                       | 87/1500 [00:26<07:01,  3.35it/s, loss=2.83e+3]
# Epoch:   6%|███▍                                                       | 87/1500 [00:26<07:01,  3.35it/s, loss=2.82e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.46it/s]
# Epoch:   6%|███▍                                                       | 88/1500 [00:27<06:33,  3.59it/s, loss=2.82e+3]
# Epoch:   6%|███▍                                                       | 88/1500 [00:27<06:33,  3.59it/s, loss=2.81e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.78it/s]
# Epoch:   6%|███▌                                                       | 89/1500 [00:27<07:10,  3.28it/s, loss=2.81e+3]
# Epoch:   6%|███▌                                                        | 89/1500 [00:27<07:10,  3.28it/s, loss=2.8e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.66it/s]
# Epoch:   6%|███▌                                                        | 90/1500 [00:27<07:00,  3.35it/s, loss=2.8e+3]
# Epoch:   6%|███▌                                                       | 90/1500 [00:27<07:00,  3.35it/s, loss=2.78e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.18it/s]
# Epoch:   6%|███▌                                                       | 91/1500 [00:27<06:37,  3.55it/s, loss=2.78e+3]
# Epoch:   6%|███▌                                                       | 91/1500 [00:27<06:37,  3.55it/s, loss=2.77e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.95it/s]
# Epoch:   6%|███▌                                                       | 92/1500 [00:28<06:26,  3.64it/s, loss=2.77e+3]
# Epoch:   6%|███▌                                                       | 92/1500 [00:28<06:26,  3.64it/s, loss=2.76e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.46it/s]
# Epoch:   6%|███▋                                                       | 93/1500 [00:28<06:08,  3.82it/s, loss=2.76e+3]
# Epoch:   6%|███▋                                                       | 93/1500 [00:28<06:08,  3.82it/s, loss=2.75e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.18it/s]
# Epoch:   6%|███▋                                                       | 94/1500 [00:28<06:00,  3.90it/s, loss=2.75e+3]
# Epoch:   6%|███▋                                                       | 94/1500 [00:28<06:00,  3.90it/s, loss=2.74e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.00it/s]
# Epoch:   6%|███▋                                                       | 95/1500 [00:28<06:00,  3.89it/s, loss=2.74e+3]
# Epoch:   6%|███▋                                                       | 95/1500 [00:28<06:00,  3.89it/s, loss=2.73e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.97it/s]
# Epoch:   6%|███▊                                                       | 96/1500 [00:29<06:01,  3.89it/s, loss=2.73e+3]
# Epoch:   6%|███▊                                                       | 96/1500 [00:29<06:01,  3.89it/s, loss=2.71e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.88it/s]
# Epoch:   6%|███▊                                                       | 97/1500 [00:29<06:04,  3.84it/s, loss=2.71e+3]
# Epoch:   6%|███▉                                                        | 97/1500 [00:29<06:04,  3.84it/s, loss=2.7e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.05it/s]
# Epoch:   7%|███▉                                                        | 98/1500 [00:29<06:02,  3.87it/s, loss=2.7e+3]
# Epoch:   7%|███▊                                                       | 98/1500 [00:29<06:02,  3.87it/s, loss=2.69e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.12it/s]
# Epoch:   7%|███▉                                                       | 99/1500 [00:29<05:59,  3.90it/s, loss=2.69e+3]
# Epoch:   7%|███▉                                                       | 99/1500 [00:30<05:59,  3.90it/s, loss=2.68e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.18it/s]
# Epoch:   7%|███▊                                                      | 100/1500 [00:30<05:55,  3.94it/s, loss=2.68e+3]
# Epoch:   7%|███▉                                                       | 100/1500 [00:30<05:55,  3.94it/s, loss=2669.0]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.76it/s]
# Epoch:   7%|███▉                                                       | 101/1500 [00:30<06:04,  3.84it/s, loss=2669.0]
# Epoch:   7%|███▉                                                      | 101/1500 [00:30<06:04,  3.84it/s, loss=2.66e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.07it/s]
# Epoch:   7%|███▉                                                      | 102/1500 [00:30<06:01,  3.87it/s, loss=2.66e+3]
# Epoch:   7%|███▉                                                      | 102/1500 [00:30<06:01,  3.87it/s, loss=2.65e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.79it/s]
# Epoch:   7%|███▉                                                      | 103/1500 [00:30<06:06,  3.82it/s, loss=2.65e+3]
# Epoch:   7%|███▉                                                      | 103/1500 [00:31<06:06,  3.82it/s, loss=2.64e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4
/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▊| 1496/1500 [07:01<00:01,  3.52it/s, loss=614]
# Epoch: 100%|████████████████████████████████████████████████████████████▊| 1496/1500 [07:01<00:01,  3.52it/s, loss=614]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.54it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1497/1500 [07:02<00:00,  3.49it/s, loss=614]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1497/1500 [07:02<00:00,  3.49it/s, loss=614]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.09it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1498/1500 [07:02<00:00,  3.33it/s, loss=614]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1498/1500 [07:02<00:00,  3.33it/s, loss=613]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.24it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1499/1500 [07:02<00:00,  3.28it/s, loss=613]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 1499/1500 [07:02<00:00,  3.28it/s, loss=613]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.07it/s]
# Done Training!

# %%
model.eval()
likelihood.eval()
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
torch.save(model.state_dict(), "helens_2_derivatives.model")

# %% [markdown]
# # Predict

# %%
x.size(-2)
# Out:
# 900

# %%
test_loader  = DataLoader(test_dataset, batch_size=n_test, shuffle=True)
# predict in batches
kwargs = {}
derivative_directions = torch.eye(dim)[:num_directions]
derivative_directions = derivative_directions.repeat(n_test,1)
print(derivative_directions.shape)
# Out:
# torch.Size([90, 2])

# %%
kwargs['derivative_directions'] = derivative_directions
#means   = model(test_x, **kwargs).mean.cpu()
means = torch.tensor([0.])
test_y = torch.zeros(1,dim+1)
test_x = torch.zeros(1,dim)
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        preds = model(x_batch,**kwargs)
        means = torch.cat([means, preds.mean.cpu()])
        test_y = torch.cat([test_y, y_batch])
        test_x = torch.cat([test_x, x_batch])

means = means[1:]
test_y = test_y[1:]
test_x = test_x[1:]
# Out:
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  1
# num_directions is:  1

# %%
# compute MSE
test_mse = MSE(test_y[:,0],means[::num_directions+1])
print(f"\nTesting MSE: {test_mse}")
print(f"\nTesting RMSE: {math.sqrt(test_mse)}")
test_mae = MAE(test_y[:,0],means[::num_directions+1])
print(f"\nTesting MAE: {test_mae}")
# Out:
# Testing MSE: 16054.2412109375
#
# Testing RMSE: 126.70533221193772
#
# Testing MAE: 101.81449890136719

# %%
# testing RMSE is 364 for 1000 epochs...
# 300 inducing, 900 datapoints, 10% test, 1500 epochs: MAE = 101, MSE = 126
#I suspect that 1500 epochs is not enough. Try 4000 if I have time...

# %% [markdown]
# # Plot Actual vs Prediction

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(train_x[:,0],train_x[:,1],train_y[:,0], color='k')
ax.scatter(train_x[:,0],train_x[:,1],preds.detach().numpy()[::num_directions+1], color='b')
plt.title("f(x,y) variational fit; actual curve is black, variational is blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-de2f99bb2965> in <module>
#       3 fig = plt.figure(figsize=(12,6))
#       4 ax = fig.add_subplot(111, projection='3d')
# ----> 5 ax.scatter(train_x[:,0],train_x[:,1],train_y[:,0], color='k')
#       6 ax.scatter(train_x[:,0],train_x[:,1],preds.detach().numpy()[::num_directions+1], color='b')
#       7 plt.title("f(x,y) variational fit; actual curve is black, variational is blue")
#
# NameError: name 'train_x' is not defined

# %%
x = torch.tensor([-1, -2, -3]).abs()

# %%
x
# Out:
# tensor([1, 2, 3])
