# %% [markdown]
# # Mount St. Helens Countour Dataset

# %%
import math
import numpy as np
import torch
import gpytorch
import tqdm
import random
from matplotlib import pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
import sys
import sys
import scipy.io
import torch
import numpy as np 
sys.path.append("../directionalvi")
#sys.path.append("../../data")
sys.path.append("../directionalvi/utils")
from directional_vi import train_gp
from metrics import MSE
from metrics import MAE
# Out:
# in Directional Grad Variational Strategy.py

# %%
#load data
mat = scipy.io.loadmat('MtSH.mat')
x = torch.tensor(np.float64(mat['mth_points'])).float()
y = torch.tensor(np.float64(mat['mth_verts'])).float()
y = y - torch.mean(y)
dy = torch.tensor(np.float64(mat['mth_grads'])).float()
data = torch.cat((y, dy), dim = 1).float()
full_data = torch.cat((x, data), dim=1).float() #location concatenated with y and dy values

# %% [markdown]
# # Filter and Round Dataset (If Applicable)

# %%
temp_full_data = np.array(full_data)
def fun(x, val = 250):
    if x[0]>250 or x[1]>250:       
        return False 
    else:
        return True
filtered = filter(fun, temp_full_data)
#for item in filtered:
#    print(item)
arr = [item for item in filtered]
len_arr = len(arr)
len_arr = len_arr - len_arr%100
arr = arr[:len_arr]
#full_data_truncated = torch.tensor(arr)
print(len(arr))
# Out:
# 900

# %%
xs1 = [item[0] for item in arr]
xs2 = [item[1] for item in arr]
plt.scatter(xs1, xs2)

# %%
#recover x and data from filtered concatenated values
x = torch.tensor([item[0:2] for item in arr])
data = torch.tensor([item[2:] for item in arr])
data[:, 0] = data[:, 0] - torch.mean(data[:, 0]) #normalize
print(max(data[:, 0]))
print(min(data[:, 0]))
# Out:
# tensor(412.5541)
# tensor(-225.6771)

# %%
# data parameters
n  = data.shape[0] 
dim = 2
n_test = n//10

# training params
num_inducing = 400
num_directions = dim
minibatch_size = n_test #how does minibatch size impact convergence rate
num_epochs = 4000

#print
print("n is: ", n)
print("n_test is: ", n_test)
print("num_inducing is:", num_inducing)
print("num_directions is: ", num_directions)

# generate training data
dataset = TensorDataset(x, data)
# Out:
# n is:  1300
# n_test is:  130
# num_inducing is: 400
# num_directions is:  2

# %% [markdown]
# # Plotting

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [n_test, n-n_test], generator=torch.Generator().manual_seed(42))

# %%
train_dataset
train_loader  = DataLoader(train_dataset, batch_size=minibatch_size, shuffle=True)
dim = len(train_dataset[0][0])
n_samples = len(train_dataset)

# %%
n_samples
# Out:
# 90

# %%
model,likelihood = train_gp(train_dataset,
                      num_inducing=num_inducing,
                      num_directions=num_directions,
                      minibatch_size = minibatch_size,
                      minibatch_dim = num_directions,
                      num_epochs =num_epochs
                      )
# Out:
# Epoch:   0%|                                                                                  | 0/4000 [00:00<?, ?it/s]
# Minibatch:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Epoch:   0%|                                                                    | 0/4000 [00:00<?, ?it/s, loss=3.12e+3]
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.45it/s]
# Epoch:   0%|                                                            | 1/4000 [00:00<46:31,  1.43it/s, loss=3.12e+3]
# Epoch:   0%|                                                             | 1/4000 [00:00<46:31,  1.43it/s, loss=3.1e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   0%|                                                             | 2/4000 [00:01<43:09,  1.54it/s, loss=3.1e+3]
# Epoch:   0%|                                                            | 2/4000 [00:01<43:09,  1.54it/s, loss=3.07e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.36it/s]
# Epoch:   0%|                                                            | 3/4000 [00:01<45:08,  1.48it/s, loss=3.07e+3]
# Epoch:   0%|                                                            | 3/4000 [00:02<45:08,  1.48it/s, loss=3.05e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.62it/s]
# Epoch:   0%|                                                            | 4/4000 [00:02<44:09,  1.51it/s, loss=3.05e+3]
# Epoch:   0%|                                                            | 4/4000 [00:02<44:09,  1.51it/s, loss=3.03e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.76it/s]
# Epoch:   0%|                                                            | 5/4000 [00:03<42:23,  1.57it/s, loss=3.03e+3]
# Epoch:   0%|                                                            | 5/4000 [00:03<42:23,  1.57it/s, loss=3.01e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.69it/s]
# Epoch:   0%|                                                            | 6/4000 [00:03<41:40,  1.60it/s, loss=3.01e+3]
# Epoch:   0%|                                                            | 6/4000 [00:03<41:40,  1.60it/s, loss=2.99e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.72it/s]
# Epoch:   0%|                                                            | 7/4000 [00:04<40:57,  1.62it/s, loss=2.99e+3]
# Epoch:   0%|                                                            | 7/4000 [00:04<40:57,  1.62it/s, loss=2.97e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.73it/s]
# Epoch:   0%|                                                            | 8/4000 [00:04<40:26,  1.65it/s, loss=2.97e+3]
# Minibatch:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Epoch:   0%|                                                            | 8/4000 [00:05<40:26,  1.65it/s, loss=2.95e+3]
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.47it/s]
# Epoch:   0%|▏                                                           | 9/4000 [00:05<42:03,  1.58it/s, loss=2.95e+3]
# Epoch:   0%|▏                                                           | 9/4000 [00:05<42:03,  1.58it/s, loss=2.93e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.78it/s]
# Epoch:   0%|▏                                                          | 10/4000 [00:06<40:49,  1.63it/s, loss=2.93e+3]
# Epoch:   0%|▏                                                           | 10/4000 [00:06<40:49,  1.63it/s, loss=2.9e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.51it/s]
# Epoch:   0%|▏                                                           | 11/4000 [00:06<41:58,  1.58it/s, loss=2.9e+3]
# Epoch:   0%|▏                                                          | 11/4000 [00:07<41:58,  1.58it/s, loss=2.88e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.54it/s]
# Epoch:   0%|▏                                                          | 12/4000 [00:07<42:28,  1.56it/s, loss=2.88e+3]
# Epoch:   0%|▏                                                          | 12/4000 [00:07<42:28,  1.56it/s, loss=2.86e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.63it/s]
# Epoch:   0%|▏                                                          | 13/4000 [00:08<42:16,  1.57it/s, loss=2.86e+3]
# Epoch:   0%|▏                                                          | 13/4000 [00:08<42:16,  1.57it/s, loss=2.85e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.56it/s]
# Epoch:   0%|▏                                                          | 14/4000 [00:08<42:33,  1.56it/s, loss=2.85e+3]
# Epoch:   0%|▏                                                          | 14/4000 [00:09<42:33,  1.56it/s, loss=2.83e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.68it/s]
# Epoch:   0%|▏                                                          | 15/4000 [00:09<41:50,  1.59it/s, loss=2.83e+3]
# Epoch:   0%|▏                                                          | 15/4000 [00:09<41:50,  1.59it/s, loss=2.81e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.86it/s]
# Epoch:   0%|▏                                                          | 16/4000 [00:09<40:11,  1.65it/s, loss=2.81e+3]
# Minibatch:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Epoch:   0%|▏                                                          | 16/4000 [00:10<40:11,  1.65it/s, loss=2.79e+3]
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1
+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.90it/s]
# Epoch:   1%|▋                                                          | 46/4000 [00:27<35:07,  1.88it/s, loss=2.32e+3]
# Epoch:   1%|▋                                                          | 46/4000 [00:27<35:07,  1.88it/s, loss=2.31e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.93it/s]
# Epoch:   1%|▋                                                          | 47/4000 [00:28<34:59,  1.88it/s, loss=2.31e+3]
# Epoch:   1%|▋                                                           | 47/4000 [00:28<34:59,  1.88it/s, loss=2.3e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.88it/s]
# Epoch:   1%|▋                                                           | 48/4000 [00:28<35:10,  1.87it/s, loss=2.3e+3]
# Epoch:   1%|▋                                                          | 48/4000 [00:28<35:10,  1.87it/s, loss=2.28e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.88it/s]
# Epoch:   1%|▋                                                          | 49/4000 [00:29<35:18,  1.87it/s, loss=2.28e+3]
# Epoch:   1%|▋                                                          | 49/4000 [00:29<35:18,  1.87it/s, loss=2.27e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.96it/s]
# Epoch:   1%|▋                                                          | 50/4000 [00:29<34:59,  1.88it/s, loss=2.27e+3]
# Epoch:   1%|▋                                                          | 50/4000 [00:29<34:59,  1.88it/s, loss=2.26e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.93it/s]
# Epoch:   1%|▊                                                          | 51/4000 [00:30<34:51,  1.89it/s, loss=2.26e+3]
# Epoch:   1%|▊                                                          | 51/4000 [00:30<34:51,  1.89it/s, loss=2.25e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.75it/s]
# Epoch:   1%|▊                                                          | 52/4000 [00:30<35:51,  1.84it/s, loss=2.25e+3]
# Epoch:   1%|▊                                                          | 52/4000 [00:30<35:51,  1.84it/s, loss=2.23e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.01it/s]
# Epoch:   1%|▊                                                          | 53/4000 [00:31<35:04,  1.88it/s, loss=2.23e+3]
# Epoch:   1%|▊                                                          | 53/4000 [00:31<35:04,  1.88it/s, loss=2222.25]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.90it/s]
# Epoch:   1%|▊                                                          | 54/4000 [00:31<35:08,  1.87it/s, loss=2222.25]
# Epoch:   1%|▊                                                          | 54/4000 [00:32<35:08,  1.87it/s, loss=2.21e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.93it/s]
# Epoch:   1%|▊                                                          | 55/4000 [00:32<34:58,  1.88it/s, loss=2.21e+3]
# Epoch:   1%|▊                                                           | 55/4000 [00:32<34:58,  1.88it/s, loss=2.2e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.85it/s]
# Epoch:   1%|▊                                                           | 56/4000 [00:32<35:20,  1.86it/s, loss=2.2e+3]
# Epoch:   1%|▊                                                          | 56/4000 [00:33<35:20,  1.86it/s, loss=2.19e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.94it/s]
# Epoch:   1%|▊                                                          | 57/4000 [00:33<35:02,  1.88it/s, loss=2.19e+3]
# Epoch:   1%|▊                                                          | 57/4000 [00:33<35:02,  1.88it/s, loss=2.18e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.89it/s]
# Epoch:   1%|▊                                                          | 58/4000 [00:34<35:03,  1.87it/s, loss=2.18e+3]
# Epoch:   1%|▊                                                          | 58/4000 [00:34<35:03,  1.87it/s, loss=2.16e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   1%|▊                                                          | 59/4000 [00:34<34:58,  1.88it/s, loss=2.16e+3]
# Epoch:   1%|▊                                                          | 59/4000 [00:34<34:58,  1.88it/s, loss=2.15e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.92it/s]
# Epoch:   2%|▉                                                          | 60/4000 [00:35<34:53,  1.88it/s, loss=2.15e+3]
# Epoch:   2%|▉                                                          | 60/4000 [00:35<34:53,  1.88it/s, loss=2.14e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.62it/s]
# Epoch:   2%|▉                                                          | 61/4000 [00:35<36:47,  1.78it/s, loss=2.14e+3]
# Epoch:   2%|▉                                                          | 61/4000 [00:35<36:47,  1.78it/s, loss=2.13e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.00it/s]
# Epoch:   2%|▉                                                          | 62/4000 [00:36<35:42,  1.84it/s, loss=2.13e+3]
# Epoch:   2%|▉                                                          | 62/4000 [00:36<35:42,  1.84it/s, loss=2.12e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.83it/s]
# Epoch:   2%|▉                                                          | 63/4000 [00:36<35:57,  1.82it/s, loss=2.12e+3]
# Epoch:   2%|▉                                                          | 63/4000 [00:36<35:57,  1.82it/s, loss=2.11e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.83it/s]
# Epoch:   2%|▉                                                          | 64/4000 [00:37<36:01,  1.82it/s, loss=2.11e+3]
# Epoch:   2%|▉                                                           | 64/4000 [00:37<36:01,  1.82it/s, loss=2.1e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.86it/s]
# Epoch:   2%|▉                                                           | 65/4000 [00:37<35:57,  1.82it/s, loss=2.1e+3]
# Epoch:   2%|▉                                                          | 65/4000 [00:38<35:57,  1.82it/s, loss=2.09e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.89it/s]
# Epoch:   2%|▉                                                          | 66/4000 [00:38<35:42,  1.84it/s, loss=2.09e+3]
# Epoch:   2%|▉                                                          | 66/4000 [00:38<35:42,  1.84it/s, loss=2.08e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.82it/s]
# Epoch:   2%|▉                                                          | 67/4000 [00:38<35:54,  1.83it/s, loss=2.08e+3]
# Epoch:   2%|▉                                                          | 67/4000 [00:39<35:54,  1.83it/s, loss=2.07e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.90it/s]
# Epoch:   2%|█                                                          | 68/4000 [00:39<35:38,  1.84it/s, loss=2.07e+3]
# Epoch:   2%|█                                                          | 68/4000 [00:39<35:38,  1.84it/s, loss=2.06e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.75it/s]
# Epoch:   2%|█                                                          | 69/4000 [00:40<36:18,  1.80it/s, loss=2.06e+3]
# Epoch:   2%|█                                                          | 69/4000 [00:40<36:18,  1.80it/s, loss=2.05e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.75it/s]
# Epoch:   2%|█                                                          | 70/4000 [00:40<36:47,  1.78it/s, loss=2.05e+3]
# Epoch:   2%|█                                                          | 70/4000 [00:40<36:47,  1.78it/s, loss=2.04e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.88it/s]
# Epoch:   2%|█                                                          | 71/4000 [00:41<36:19,  1.80it/s, loss=2.04e+3]
# Epoch:   2%|█                                                          | 71/4000 [00:41<36:19,  1.80it/s, loss=2.03e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.82it/s]
# Epoch:   2%|█                                                          | 72/4000 [00:41<36:24,  1.80it/s, loss=2.03e+3]
# Epoch:   2%|█                                                          | 72/4000 [00:41<36:24,  1.80it/s, loss=2.02e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.77it/s]
# Epoch:   2%|█                                                          | 73/4000 [00:42<36:42,  1.78it/s, loss=2.02e+3]
# Epoch:   2%|█                                                          | 73/4000 [00:42<36:42,  1.78it/s, loss=2.01e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   2%|█                                                          | 74/4000 [00:42<36:07,  1.81it/s, loss=2.01e+3]
# Epoch:   2%|█▏                                                            | 74/4000 [00:42<36:07,  1.81it/s, loss=2e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.83it/s]
# Epoch:   2%|█▏                                                            | 75/4000 [00:43<36:09,  1.81it/s, loss=2e+3]
# Epoch:   2%|█                                                          | 75/4000 [00:43<36:09,  1.81it/s, loss=1.99e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.85it/s]
# Epoch:   2%|█                                                          | 76/4000 [00:43<36:04,  1.81it/s, loss=1.99e+3]
# Epoch:   2%|█                                                          | 76/4000 [00:44<36:04,  1.81it/s, loss=1.98e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.88it/s]
# Epoch:   2%|█▏                                                         | 77/4000 [00:44<35:55,  1.82it/s, loss=1.98e+3]
# Epoch:   2%|█▏                                                         | 77/4000 [00:44<35:55,  1.82it/s, loss=1.97e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.83it/s]
# Epoch:   2%|█▏                                                         | 78/4000 [00:45<36:01,  1.81it/s, loss=1.97e+3]
# Epoch:   2%|█▏                                                         | 78/4000 [00:45<36:01,  1.81it/s, loss=1.96e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.78it/s]
# Epoch:   2%|█▏                                                         | 79/4000 [00:45<36:22,  1.80it/s, loss=1.96e+3]
# Epoch:   2%|█▏                                                         | 79/4000 [00:45<36:22,  1.80it/s, loss=1.95e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▏                                                         | 80/4000 [00:46<36:05,  1.81it/s, loss=1.95e+3]
# Epoch:   2%|█▏                                                         | 80/4000 [00:46<36:05,  1.81it/s, loss=1.94e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.88it/s]
# Epoch:   2%|█▏                                                         | 81/4000 [00:46<35:47,  1.82it/s, loss=1.94e+3]
# Epoch:   2%|█▏                                                         | 81/4000 [00:46<35:47,  1.82it/s, loss=1.93e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▏                                                         | 82/4000 [00:47<35:42,  1.83it/s, loss=1.93e+3]
# Epoch:   2%|█▏                                                         | 82/4000 [00:47<35:42,  1.83it/s, loss=1.92e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.84it/s]
# Epoch:   2%|█▏                                                         | 83/4000 [00:47<35:46,  1.82it/s, loss=1.92e+3]
# Epoch:   2%|█▏                                                         | 83/4000 [00:47<35:46,  1.82it/s, loss=1.92e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.89it/s]
# Epoch:   2%|█▏                                                         | 84/4000 [00:48<35:30,  1.84it/s, loss=1.92e+3]
# Epoch:   2%|█▏                                                         | 84/4000 [00:48<35:30,  1.84it/s, loss=1.91e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▎                                                         | 85/4000 [00:48<35:26,  1.84it/s, loss=1.91e+3]
# Epoch:   2%|█▎                                                          | 85/4000 [00:49<35:26,  1.84it/s, loss=1.9e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   2%|█▎                                                          | 86/4000 [00:49<35:16,  1.85it/s, loss=1.9e+3]
# Epoch:   2%|█▎                                                         | 86/4000 [00:49<35:16,  1.85it/s, loss=1.89e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▎                                                         | 87/4000 [00:49<35:16,  1.85it/s, loss=1.89e+3]
# Epoch:   2%|█▎                                                         | 87/4000 [00:50<35:16,  1.85it/s, loss=1.88e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.83it/s]
# Epoch:   2%|█▎                                                         | 88/4000 [00:50<35:29,  1.84it/s, loss=1.88e+3]
# Epoch:   2%|█▎                                                         | 88/4000 [00:50<35:29,  1.84it/s, loss=1.87e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.81it/s]
# Epoch:   2%|█▎                                                         | 89/4000 [00:51<35:48,  1.82it/s, loss=1.87e+3]
# Epoch:   2%|█▎                                                         | 89/4000 [00:51<35:48,  1.82it/s, loss=1.87e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.89it/s]
# Epoch:   2%|█▎                                                         | 90/4000 [00:51<35:32,  1.83it/s, loss=1.87e+3]
# Epoch:   2%|█▎                                                         | 90/4000 [00:51<35:32,  1.83it/s, loss=1.86e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▎                                                         | 91/4000 [00:52<35:29,  1.84it/s, loss=1.86e+3]
# Epoch:   2%|█▎                                                         | 91/4000 [00:52<35:29,  1.84it/s, loss=1.85e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.96it/s]
# Epoch:   2%|█▎                                                         | 92/4000 [00:52<34:59,  1.86it/s, loss=1.85e+3]
# Epoch:   2%|█▎                                                         | 92/4000 [00:52<34:59,  1.86it/s, loss=1.84e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.87it/s]
# Epoch:   2%|█▎                                                         | 93/4000 [00:53<35:10,  1.85it/s, loss=1.84e+3]
# Epoch:   2%|█▎                                                         | 93/4000 [00:53<35:10,  1.85it/s, loss=1.83e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.93it/s]
# Epoch:   2%|█▍                                                         | 94/4000 [00:53<34:54,  1.87it/s, loss=1.83e+3]
# Epoch:   2%|█▍                                                         | 94/4000 [00:53<34:54,  1.87it/s, loss=1.83e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   2%|█▍                                                         | 95/4000 [00:54<34:47,  1.87it/s, loss=1.83e+3]
# Epoch:   2%|█▍                                                         | 95/4000 [00:54<34:47,  1.87it/s, loss=1.82e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.95it/s]
# Epoch:   2%|█▍                                                         | 96/4000 [00:54<34:33,  1.88it/s, loss=1.82e+3]
# Epoch:   2%|█▍                                                         | 96/4000 [00:54<34:33,  1.88it/s, loss=1.81e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.95it/s]
# Epoch:   2%|█▍                                                         | 97/4000 [00:55<34:22,  1.89it/s, loss=1.81e+3]
# Epoch:   2%|█▍                                                          | 97/4000 [00:55<34:22,  1.89it/s, loss=1.8e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.78it/s]
# Epoch:   2%|█▍                                                          | 98/4000 [00:55<35:11,  1.85it/s, loss=1.8e+3]
# Epoch:   2%|█▍                                                          | 98/4000 [00:56<35:11,  1.85it/s, loss=1.8e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.99it/s]
# Epoch:   2%|█▍                                                          | 99/4000 [00:56<34:34,  1.88it/s, loss=1.8e+3]
# Epoch:   2%|█▍                                                         | 99/4000 [00:56<34:34,  1.88it/s, loss=1.79e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.93it/s]
# Epoch:   2%|█▍                                                        | 100/4000 [00:56<34:28,  1.89it/s, loss=1.79e+3]
# Epoch:   2%|█▍                                                        | 100/4000 [00:57<34:28,  1.89it/s, loss=1.78e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.91it/s]
# Epoch:   3%|█▍                                                        | 101/4000 [00:57<34:28,  1.88it/s, loss=1.78e+3]
# Epoch:   3%|█▍                                                        | 101/4000 [00:57<34:28,  1.88it/s, loss=1.77e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.94it/s]
# Epoch:   3%|█▍                                                        | 102/4000 [00:57<34:20,  1.89it/s, loss=1.77e+3]
# Epoch:   3%|█▍                                                        | 102/4000 [00:58<34:20,  1.89it/s, loss=1.77e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.92it/s]
# Epoch:   3%|█▍                                                        | 103/4000 [00:58<34:22,  1.89it/s, loss=1.77e+3]
# Epoch:   3%|█▍                                                        | 103/4000 [00:58<34:22,  1.89it/s, loss=1.76e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.92it/s]
# Epoch:   3%|█▌                                                        | 104/4000 [00:59<34:23,  1.89it/s, loss=1.76e+3]
# Epoch:   3%|█▌                                                        | 104/4000 [00:59<34:23,  1.89it/s, loss=1.75e+3]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.99it/s]
# Epoch:   3%|█▌                                                        | 105/4000 [00:59<34:00,  1.91it/s, loss=1.75e+3]
# ...
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.69it/s]
# Epoch:  99%|████████████████████████████████████████████████████████████▍|
/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3996/4000 [36:20<00:01,  2.02it/s, loss=211]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3996/4000 [36:20<00:01,  2.02it/s, loss=211]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.15it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3997/4000 [36:21<00:01,  2.05it/s, loss=211]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3997/4000 [36:21<00:01,  2.05it/s, loss=211]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.04it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3998/4000 [36:21<00:00,  2.04it/s, loss=211]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3998/4000 [36:21<00:00,  2.04it/s, loss=211]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.12it/s]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3999/4000 [36:22<00:00,  2.05it/s, loss=211]
# Epoch: 100%|████████████████████████████████████████████████████████████▉| 3999/4000 [36:22<00:00,  2.05it/s, loss=211]
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# Minibatch: 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.98it/s]
# Done Training!

# %%
model.eval()
likelihood.eval()
# Out:
# GaussianLikelihood(
#   (noise_covar): HomoskedasticNoise(
#     (raw_noise_constraint): GreaterThan(1.000E-04)
#   )
# )

# %%
torch.save(model.state_dict(), "helens_2_derivatives.model")

# %% [markdown]
# # Predict

# %%
x.size(-2)
# Out:
# 900

# %%
test_loader  = DataLoader(test_dataset, batch_size=n_test, shuffle=True)
# predict in batches
kwargs = {}
derivative_directions = torch.eye(dim)[:num_directions]
derivative_directions = derivative_directions.repeat(n_test,1)
print(derivative_directions.shape)
# Out:
# torch.Size([180, 2])

# %%
kwargs['derivative_directions'] = derivative_directions
#means   = model(test_x, **kwargs).mean.cpu()
means = torch.tensor([0.])
test_y = torch.zeros(1,dim+1)
test_x = torch.zeros(1,dim)
with torch.no_grad():
    for x_batch, y_batch in test_loader:
        preds = model(x_batch,**kwargs)
        means = torch.cat([means, preds.mean.cpu()])
        test_y = torch.cat([test_y, y_batch])
        test_x = torch.cat([test_x, x_batch])

means = means[1:]
test_y = test_y[1:]
test_x = test_x[1:]
# Out:
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2
# num_induc is:  400
# num_data is:  90
# num_derivative_directions is:  2
# num_directions is:  2

# %%
# compute MSE
test_mse = MSE(test_y[:,0],means[::num_directions+1])
print(f"\nTesting MSE: {test_mse}")
print(f"\nTesting RMSE: {math.sqrt(test_mse)}")
test_mae = MAE(test_y[:,0],means[::num_directions+1])
print(f"\nTesting MAE: {test_mae}")
# Out:
# Testing MSE: 16052.6767578125
#
# Testing RMSE: 126.69915847318205
#
# Testing MAE: 101.95784759521484

# %%
# testing RMSE is 364 for 1000 epochs...
# 300 inducing, 900 datapoints, 10% test, 1500 epochs: MAE = 101, MSE = 126
#I suspect that 1500 epochs is not enough. Try 4000 if I have time...

# %% [markdown]
# # Plot Actual vs Prediction

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(train_x[:,0],train_x[:,1],train_y[:,0], color='k')
ax.scatter(train_x[:,0],train_x[:,1],preds.detach().numpy()[::num_directions+1], color='b')
plt.title("f(x,y) variational fit; actual curve is black, variational is blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-de2f99bb2965> in <module>
#       3 fig = plt.figure(figsize=(12,6))
#       4 ax = fig.add_subplot(111, projection='3d')
# ----> 5 ax.scatter(train_x[:,0],train_x[:,1],train_y[:,0], color='k')
#       6 ax.scatter(train_x[:,0],train_x[:,1],preds.detach().numpy()[::num_directions+1], color='b')
#       7 plt.title("f(x,y) variational fit; actual curve is black, variational is blue")
#
# NameError: name 'train_x' is not defined

# %%
x = torch.tensor([-1, -2, -3]).abs()

# %%
x
