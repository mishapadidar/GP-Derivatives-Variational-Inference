# %%
from load_data import *

# %%
args= {'seed': 123, 'n_train': 700, 'derivative': True}

# %%
res = load_helens("../../data/helens", 0.5, **args)

# %%
res
# Out:
# (<torch.utils.data.dataset.Subset at 0x22f0d664fc8>,
# ...
#  2)

# %%
for item in res[1]:
    print(item)
# Out:
# (tensor([0.1000, 0.0427]), tensor([ 3.7536e-01,  5.3329e-04, -3.0831e-04]))
# (tensor([0.1500, 0.2564]), tensor([ 5.7359e-01, -4.0984e-05,  2.0976e-03]))
# (tensor([0.0667, 0.1709]), tensor([ 4.0946e-01, -4.7495e-04,  1.8311e-04]))
# (tensor([0.4333, 0.3248]), tensor([0.7823, 0.0011, 0.0015]))
# (tensor([0.1667, 0.1282]), tensor([4.3560e-01, 3.4381e-04, 4.0052e-04]))
# (tensor([0.1000, 0.4872]), tensor([5.4246e-01, 9.0209e-04, 2.9285e-04]))
# (tensor([0.3500, 0.1709]), tensor([5.2228e-01, 4.6842e-04, 1.6121e-03]))
# (tensor([0.3667, 0.1624]), tensor([5.2037e-01, 1.2445e-03, 3.0956e-04]))
# (tensor([0.1833, 0.1197]), tensor([4.3127e-01, 2.4943e-04, 3.6225e-04]))
# (tensor([0.3250, 0.2479]), tensor([5.7055e-01, 9.5040e-04, 4.6437e-04]))
# (tensor([0.3083, 0.2821]), tensor([5.9816e-01, 7.0553e-04, 5.3750e-04]))
# (tensor([0.3417, 0.2479]), tensor([0.5795, 0.0017, 0.0007]))
# (tensor([0.1083, 0.4017]), tensor([5.2632e-01, 2.3858e-04, 9.1012e-04]))
# ...
